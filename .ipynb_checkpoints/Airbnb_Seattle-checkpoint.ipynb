# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in /opt/anaconda3/lib/python3.9/site-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /opt/anaconda3/lib/python3.9/site-packages (from textblob) (3.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.9/site-packages (from nltk>=3.1->textblob) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.9/site-packages (from nltk>=3.1->textblob) (2022.7.9)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.9/site-packages (from nltk>=3.1->textblob) (4.64.1)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.9/site-packages (from nltk>=3.1->textblob) (8.0.4)

# %%
# Import dependencies
import pandas as pd
import numpy as np
import pymysql as mysql
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings
import getpass
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Connecting pandas to MySQL database

# %%
conn = mysql.connect(host='localhost',
                    port = int(3306),
                    user = 'root',
                    passwd=getpass.getpass('Enter password:'),
                    db="Airbnb_DB")

df = pd.read_sql_query("Show tables ", conn)
print(df)
# Out:
# Enter password:········
#   Tables_in_airbnb_db
# 0            calendar
# 1            listings
# 2             reviews

# %% [markdown]
# # Calendar

# %%
# Sql statement to extract the Calender dataset
cal_df = pd.read_sql("select * from calendar", conn)
cal_df.head(5)
# Out:
#    listing_id        date available    price  calendar_id
# 0      241032  2016-01-04         t  $85.00             1
# 1      241032  2016-01-05         t  $85.00             2
# 2      241032  2016-01-06         f     None            3
# 3      241032  2016-01-07         f     None            4
# 4      241032  2016-01-08         f     None            5

# %% [markdown]
# ### EDA Analysis

# %%
cal_df.dtypes
# Out:
# listing_id      int64
# date           object
# available      object
# price          object
# calendar_id     int64
# dtype: object

# %%
# change the data type
cal_df['date'] = pd.to_datetime(cal_df['date'])

# remove dollar sign and convert to float
cal_df['price'] = cal_df['price'].str.replace('$', '').str.replace(',','').astype(float)

# %%
cal_df.dtypes
# Out:
# listing_id              int64
# date           datetime64[ns]
# available              object
# price                 float64
# calendar_id             int64
# dtype: object

# %%
# describe
cal_df.describe()
# Out:
#          listing_id          price   calendar_id
# count  1.048575e+06  699862.000000  1.048575e+06
# mean   5.514651e+06     140.455483  5.242880e+05
# std    2.961850e+06     106.492298  3.026977e+05
# min    3.335000e+03      10.000000  1.000000e+00
# 25%    3.245876e+06      75.000000  2.621445e+05
# 50%    6.076158e+06     110.000000  5.242880e+05
# 75%    8.000037e+06     168.000000  7.864315e+05
# max    1.034016e+07    1650.000000  1.048575e+06

# %%
# shape of the dataframe
print(f'calendar dataframe shape {cal_df.shape}')
# Out:
# calendar dataframe shape (1048575, 5)

# %%
# print the null values of calendar dataset
cal_df.isnull().sum()
# Out:
# listing_id          0
# date                0
# available           0
# price          348713
# calendar_id         0
# dtype: int64

# %% [markdown]
# In the calendar dataset we have 348713 null values for the `price` column which, indicates that the listing was unavailable for particular days. We do not consider removing those columns.

# %%
# let's find out the first date and last of listing in calendar dataset 
first_date = cal_df["date"].min()
last_date = cal_df['date'].max()
print(f'The first date of listing is: {first_date}')
print(f'The first date of listing is: {last_date}')
# Out:
# The first date of listing is: 2016-01-04 00:00:00
# The first date of listing is: 2017-01-02 00:00:00

# %% [markdown]
# ### What is the average price of listings?

# %%
average_price = cal_df['price'].mean()

ax = sns.lineplot(x = "date", y = "price", data = cal_df)
ax.axhline(y=average_price, color='r', linestyle='--', label='Average Price')
plt.title('Price vs Time')
plt.xlabel('Time')
plt.ylabel('Price ($)')
# Out:
# Text(0, 0.5, 'Price ($)')

# %% [markdown]
# As we can see from the above chart, the average price for listing is around 140$. The prices goes up during summer (June, July, August, and September) which is an indication of seasonality.

# %% [markdown]
# ### The price distribution

# %%
cal_df.hist(column='price')
plt.show()

# %% [markdown]
# The majority of the prices are clustered between 0 to 270$

# %% [markdown]
# ### Which months have the highest availability during the year?

# %%
cal_df['available'] = cal_df['available'].replace({ 't': 1, 'f': 0 })
cal_df
# Out:
#          listing_id       date  available  price  calendar_id
# 0            241032 2016-01-04          1   85.0            1
# 1            241032 2016-01-05          1   85.0            2
# 2            241032 2016-01-06          0    NaN            3
# 3            241032 2016-01-07          0    NaN            4
# 4            241032 2016-01-08          0    NaN            5
# ...             ...        ...        ...    ...          ...
# 1048570     8568567 2016-11-25          1  190.0      1048571
# 1048571     8568567 2016-11-26          1  190.0      1048572
# 1048572     8568567 2016-11-27          1  140.0      1048573
# 1048573     8568567 2016-11-28          1  140.0      1048574
# 1048574     8568567 2016-11-29          1  140.0      1048575
#
# [1048575 rows x 5 columns]

# %%
availability_df = cal_df.groupby('date').sum()['available']
availability_df.plot(kind='line')
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Booking numbers start increasing from Jan till end of March, the we can see a huge drop in April. Another drop we can see in July but, after July the booking rate starts increasing

# %% [markdown]
# # Reviews

# %%
# Sql statement to extract the Calender dataset
rev_df = pd.read_sql("select * from reviews", conn)
rev_df.head(5)
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
rev_df.duplicated(subset=['reviewer_id']).sum()
# Out:
# 9119

# %%
rev_df["id"].duplicated().sum()
# Out:
# 0

# %%
rev_df.head(5)
# Out:
#    listing_id        id        date  reviewer_id reviewer_name  \
# 0     7202016  38917982  2015-07-19     28943674        Bianca
# 1     7202016  39087409  2015-07-20     32440555         Frank
# 2     7202016  39820030  2015-07-26     37722850           Ian
# 3     7202016  40813543  2015-08-02     33671805        George
# 4     7202016  41986501  2015-08-10     34959538          Ming
#
#                                             comments
# 0  Cute and cozy place. Perfect location to every...
# 1  Kelly has a great room in a very central locat...
# 2  Very spacious apartment, and in a great neighb...
# 3  Close to Seattle Center and all it has to offe...
# 4  Kelly was a great host and very accommodating ...

# %%
# change the column name
rev_df.rename(columns={'id': 'review_id'}, inplace=True)

# %%
# shape of the dataframe
print(f'calendar dataframe shape {rev_df.shape}')
# Out:
# calendar dataframe shape (84849, 6)

# %%
rev_df.isnull().sum()
# Out:
# listing_id        0
# review_id         0
# date              0
# reviewer_id       0
# reviewer_name     0
# comments         18
# dtype: int64

# %% [markdown]
# We have 18 null values in the `comments` column.

# %% [markdown]
# We have a small number of null values, removing those rows may be a reasonable option. We use dropna() function to remove rows with null values

# %%
# drop null values in comments column
rev_df_clean = rev_df.dropna(subset=['comments'])

# %%
# Check the shape of the dataframe after removing the null values
print(f'calendar dataframe shape {rev_df_clean.shape}')
# Out:
# calendar dataframe shape (84831, 6)

# %% [markdown]
# ### Sentimental Analysis to find out positive and negative comments

# %%
from textblob import TextBlob


# Define a function to get the sentiment polarity of each comment
def get_sentiment(comment):
    blob = TextBlob(comment)
    return blob.sentiment.polarity

# Create a new column with the sentiment label and use the sentiment label function on the "sentiment" column
rev_df_clean["sentiment"] = rev_df_clean["comments"].apply(get_sentiment)

# Define a function to map the polarity score to a "positive" or "negative" label
def get_sentiment_label(score):
    if score >= 0:
        return "positive"
    else:
        return "negative"

# Apply the sentiment label function to the "sentiment" column and create a new column with the sentiment label
rev_df_clean["sentiment_label"] = rev_df_clean["sentiment"].apply(get_sentiment_label)

rev_df_clean
# Out:
#        listing_id  review_id        date  reviewer_id reviewer_name  \
# 0         7202016   38917982  2015-07-19     28943674        Bianca
# 1         7202016   39087409  2015-07-20     32440555         Frank
# 2         7202016   39820030  2015-07-26     37722850           Ian
# 3         7202016   40813543  2015-08-02     33671805        George
# 4         7202016   41986501  2015-08-10     34959538          Ming
# ...           ...        ...         ...          ...           ...
# 84844     3624990   50436321  2015-10-12     37419458          Ryan
# 84845     3624990   51024875  2015-10-17      6933252         Linda
# 84846     3624990   51511988  2015-10-20     19543701         Jaime
# 84847     3624990   52814482  2015-11-02     24445024        Jørgen
# 84848     9727246   56429621  2015-12-13     30860360     Stephanie
#
#                                                 comments  sentiment  \
# 0      Cute and cozy place. Perfect location to every...   0.433333
# 1      Kelly has a great room in a very central locat...   0.301136
# 2      Very spacious apartment, and in a great neighb...   0.410417
# 3      Close to Seattle Center and all it has to offe...   0.358333
# 4      Kelly was a great host and very accommodating ...   0.493485
# ...                                                  ...        ...
# 84844  The description and pictures of the apartment ...   0.194844
# 84845  We had an excellent stay. It was clean and com...   0.311111
# 84846  Gran ubicación, cerca de todo lo atractivo del...   0.000000
# 84847  Very good apartement, clean and well sized. Si...   0.216852
# 84848  Breanne was a great host. Check in was easy, s...   0.367302
#
#       sentiment_label
# 0            positive
# 1            positive
# 2            positive
# 3            positive
# 4            positive
# ...               ...
# 84844        positive
# 84845        positive
# 84846        positive
# 84847        positive
# 84848        positive
#
# [84831 rows x 8 columns]

# %%
rev_df_clean.groupby('sentiment_label').count()['sentiment'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='sentiment_label'>

# %% [markdown]
# As we can see the above bar chart most of the users wrote positive comments for the hosts.

# %% [markdown]
# # Listings

# %%
# Sql statement to extract the Calender dataset
list_df = pd.read_sql("select * from listings", conn)

# %%
list_df["id"].duplicated().sum()
# Out:
# 0

# %%
list_df
# Out:
#             id                            listing_url       scrape_id  \
# 0       241032    https://www.airbnb.com/rooms/241032  20200000000000
# 1       953595    https://www.airbnb.com/rooms/953595  20200000000000
# 2      3308979   https://www.airbnb.com/rooms/3308979  20200000000000
# 3      7421966   https://www.airbnb.com/rooms/7421966  20200000000000
# 4       278830    https://www.airbnb.com/rooms/278830  20200000000000
# ...        ...                                    ...             ...
# 3812   8101950   https://www.airbnb.com/rooms/8101950  20200000000000
# 3813   8902327   https://www.airbnb.com/rooms/8902327  20200000000000
# 3814  10267360  https://www.airbnb.com/rooms/10267360  20200000000000
# 3815   9604740   https://www.airbnb.com/rooms/9604740  20200000000000
# 3816  10208623  https://www.airbnb.com/rooms/10208623  20200000000000
#
#      last_scraped                                 name  \
# 0      2016-01-04         Stylish Queen Anne Apartment
# 1      2016-01-04   Bright & Airy Queen Anne Apartment
# 2      2016-01-04  New Modern House-Amazing water view
# 3      2016-01-04                   Queen Anne Chateau
# 4      2016-01-04       Charming craftsman 3 bdm house
# ...           ...                                  ...
# 3812   2016-01-04   3BR Mountain View House in Seattle
# 3813   2016-01-04    Portage Bay View!-One Bedroom Apt
# 3814   2016-01-04    Private apartment view of Lake WA
# 3815   2016-01-04    Amazing View with Modern Comfort!
# 3816   2016-01-04            Large Lakefront Apartment
#
#                                                 summary  \
# 0                                                  None
# 1     Chemically sensitive? We've removed the irrita...
# 2     New modern house built in 2013.  Spectacular s...
# 3     A charming apartment that sits atop Queen Anne...
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3812  Our 3BR/2BA house boasts incredible views of t...
# 3813  800 square foot 1 bedroom basement apartment w...
# 3814  Very comfortable lower unit. Quiet, charming m...
# 3815  Cozy studio condo in the heart on Madison Park...
# 3816  All hardwood floors, fireplace, 65" TV with Xb...
#
#                                                   space  \
# 0     Make your self at home in this charming one-be...
# 1     Beautiful, hypoallergenic apartment in an extr...
# 2     Our house is modern, light and fresh with a wa...
# 3                                                  None
# 4     Cozy family craftman house in beautiful neighb...
# ...                                                 ...
# 3812  Our 3BR/2BA house bright, stylish, and wheelch...
# 3813  This space has a great view of Portage Bay wit...
# 3814                                               None
# 3815  Fully furnished unit to accommodate most needs...
# 3816                                               None
#
#                                             description experiences_offered  \
# 0     Make your self at home in this charming one-be...                none
# 1     Chemically sensitive? We've removed the irrita...                none
# 2     New modern house built in 2013.  Spectacular s...                none
# 3     A charming apartment that sits atop Queen Anne...                none
# 4     Cozy family craftman house in beautiful neighb...                none
# ...                                                 ...                 ...
# 3812  Our 3BR/2BA house boasts incredible views of t...                none
# 3813  800 square foot 1 bedroom basement apartment w...                none
# 3814  Very comfortable lower unit. Quiet, charming m...                none
# 3815  Cozy studio condo in the heart on Madison Park...                none
# 3816  All hardwood floors, fireplace, 65" TV with Xb...                none
#
#                                   neighborhood_overview  ...  \
# 0                                                  None  ...
# 1     Queen Anne is a wonderful, truly functional vi...  ...
# 2     Upper Queen Anne is a charming neighborhood fu...  ...
# 3                                                  None  ...
# 4     We are in the beautiful neighborhood of Queen ...  ...
# ...                                                 ...  ...
# 3812  We're located near lots of family fun. Woodlan...  ...
# 3813  The neighborhood is a quiet oasis that is clos...  ...
# 3814                                               None  ...
# 3815  Madison Park offers a peaceful slow pace upsca...  ...
# 3816                                               None  ...
#
#      review_scores_value requires_license license jurisdiction_names  \
# 0                   10.0                f    None         WASHINGTON
# 1                   10.0                f    None         WASHINGTON
# 2                   10.0                f    None         WASHINGTON
# 3                    NaN                f    None         WASHINGTON
# 4                    9.0                f    None         WASHINGTON
# ...                  ...              ...     ...                ...
# 3812                 8.0                f    None         WASHINGTON
# 3813                10.0                f    None         WASHINGTON
# 3814                 NaN                f    None         WASHINGTON
# 3815                 NaN                f    None         WASHINGTON
# 3816                 NaN                f    None         WASHINGTON
#
#      instant_bookable cancellation_policy  require_guest_profile_picture  \
# 0                   f            moderate                              f
# 1                   f              strict                              t
# 2                   f              strict                              f
# 3                   f            flexible                              f
# 4                   f              strict                              f
# ...               ...                 ...                            ...
# 3812                f              strict                              f
# 3813                f            moderate                              f
# 3814                f            moderate                              f
# 3815                f            moderate                              f
# 3816                f            flexible                              f
#
#      require_guest_phone_verification calculated_host_listings_count  \
# 0                                   f                              2
# 1                                   t                              6
# 2                                   f                              2
# 3                                   f                              1
# 4                                   f                              1
# ...                               ...                            ...
# 3812                                f                              8
# 3813                                f                              1
# 3814                                f                              1
# 3815                                f                              1
# 3816                                f                              1
#
#      reviews_per_month
# 0                 4.07
# 1                 1.48
# 2                 1.15
# 3                  NaN
# 4                 0.89
# ...                ...
# 3812              0.30
# 3813              2.00
# 3814               NaN
# 3815               NaN
# 3816               NaN
#
# [3817 rows x 91 columns]

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Capture Missing Values

# %%
mis_val = [x for x in list_df.columns if list_df[x].isnull().sum()>0]
list_df[mis_val].isnull().sum()
# Out:
# summary                         177
# space                           568
# neighborhood_overview          1031
# notes                          1605
# transit                         933
# thumbnail_url                   320
# medium_url                      320
# xl_picture_url                  320
# host_name                         2
# host_since                        2
# host_location                     8
# host_about                      858
# host_response_time              523
# host_response_rate              523
# host_acceptance_rate            773
# host_is_superhost                 2
# host_thumbnail_url                2
# host_picture_url                  2
# host_neighbourhood              299
# host_listings_count               2
# host_total_listings_count         2
# host_has_profile_pic              2
# host_identity_verified            2
# neighbourhood                   415
# zipcode                           7
# property_type                     1
# bathrooms                        16
# bedrooms                          6
# beds                              1
# square_feet                    3720
# weekly_price                   1808
# monthly_price                  2300
# security_deposit               1951
# cleaning_fee                   1029
# first_review                    627
# last_review                     627
# review_scores_rating            647
# review_scores_accuracy          658
# review_scores_cleanliness       653
# review_scores_checkin           658
# review_scores_communication     651
# review_scores_location          655
# review_scores_value             656
# license                        3817
# reviews_per_month               627
# dtype: int64

# %% [markdown]
# We can see plenty of missing values for multiple columns. So, in order to avoid generating synthetic data for columns which have more than 60% missing values, we will drop those columns and perform feature engineering on the rest of the data.

# %% [markdown]
# ### Dropping columns with more than 60% missing values

# %%
def drop_columns_with_max_missing_values(df):
    mis_var = [x for x in df.columns if df[x].isnull().sum() > 0]
    df[mis_var].isnull().sum()

    limit = np.abs((df.shape[0] * 0.6))
    var_to_be_dropped = [x for x in mis_var if df[x].isnull().sum() > limit]
    print('Columns with more than 60% missing values: \n\n', var_to_be_dropped)

    df.drop(columns=var_to_be_dropped, axis=1, inplace=True)
    return df

df = drop_columns_with_max_missing_values(list_df)
# Out:
# Columns with more than 60% missing values:
#
#  ['square_feet', 'monthly_price', 'license']

# %%
list_df.shape
# Out:
# (3817, 88)

# %% [markdown]
# Great! we dropped `square_feet`, `monthly_price`, `license`. As we can see the number of columns dropped from 91 to 88.

# %% [markdown]
# ### Remove the dollar signs and change the data type to float for `price`, `weekly_price`,`security_deposit`,`cleaning_fee`.

# %%
# List of columns with dollar signs
dollar_columns = ['price', 'weekly_price','security_deposit','cleaning_fee','extra_people']

# Remove dollar sign and convert to float for each column
for col in dollar_columns:
    list_df[col] = list_df[col].str.replace('$', '').str.replace(',', '').astype(float)

# %% [markdown]
# ## Listings Visualization

# %% [markdown]
# ### Analyzing the number of listing for each of the neighborhoods

# %%
neighboor_list = list_df.groupby('neighbourhood_cleansed').id.count()
neighboor_list = neighboor_list.reset_index()
neighboor_list.rename(columns={"neighbourhood_cleansed":"Neighbourhood", "id":"Count"},inplace=True)
neighboor_top10 = neighboor_list.sort_values(by="Count",ascending=False).head(10)
neighboor_top10
# Out:
#                 Neighbourhood  Count
# 9                    Broadway    397
# 4                    Belltown    234
# 79                Wallingford    167
# 21                    Fremont    158
# 47                      Minor    134
# 76        University District    122
# 74                    Stevens    119
# 20                 First Hill    108
# 12  Central Business District    103
# 38           Lower Queen Anne     94

# %%
ax = neighboor_top10.plot(x="Neighbourhood", y="Count", kind="bar")

# %% [markdown]
# These areas have the highest number of listings among the other areas.

# %% [markdown]
# ### Top 10 Neighbourhood with Highest Average Price

# %%
neighboor_price = list_df.groupby('neighbourhood_cleansed').mean()["price"]
neighboor_price = neighboor_price.reset_index()
neighboor_price
neighboor_price.rename(columns={"neighbourhood_cleansed":"Neighbourhood", "price":"average price"},inplace=True)
neighboor_price10 = neighboor_price.sort_values(by="average price",ascending=False).head(10)
neighboor_price10
# Out:
#           Neighbourhood  average price
# 73   Southeast Magnolia     231.705882
# 61          Portage Bay     227.857143
# 83             Westlake     194.470588
# 81      West Queen Anne     187.769231
# 48             Montlake     182.789474
# 6            Briarcliff     176.571429
# 75          Sunset Hill     176.055556
# 32  Industrial District     173.333333
# 1                  Alki     171.619048
# 85           Windermere     169.900000

# %%
ax = neighboor_price10.plot(x="Neighbourhood", y="average price", kind="bar")

# %% [markdown]
# ## Price prediction

# %% [markdown]
# One may gather and preprocess relevant variables like location, property type, and amenities, and then use regression-based algorithms like linear regression, decision trees, or random forest to develop a prediction model to forecast Airbnb prices in Seattle. After being trained on historical data, the model might then be tested for accuracy using measures like mean absolute error or root mean square error.
#
#
# In the given dataset, there are over 90 features/variables included, some of which may have a limited impact on predicting the price of Airbnb properties in Seattle. As such, we will identify and eliminate select columns with minimal predictive value.
# To further improve the model's accuracy, we will use feature selection techniques to identify the most significant variables for predicting Airbnb prices in Seattle

# %%
drop_cols = ['id','name', 'listing_url','scrape_id', 'host_name','last_scraped','thumbnail_url','medium_url','xl_picture_url','host_id', \
             'host_url','notes', 'transit', 'picture_url','host_about','host_response_time','host_thumbnail_url','host_verifications','street','neighbourhood', \
             'neighbourhood_group_cleansed','host_response_time', 'host_since', 'zipcode','country','latitude','market', 'experiences_offered',\
             'longitude','weekly_price','calendar_updated', 'calendar_last_scraped', 'host_picture_url',\
             'first_review','last_review', 'calculated_host_listings_count','reviews_per_month','jurisdiction_names']

# %%
list_new_df = list_df.drop(drop_cols, axis = 1)
list_new_df.columns
# Out:
# Index(['summary', 'space', 'description', 'neighborhood_overview',
#        'host_location', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_has_profile_pic',
#        'host_identity_verified', 'neighbourhood_cleansed', 'city', 'state',
#        'country_code', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'number_of_reviews',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'instant_bookable',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification'],
#       dtype='object')

# %% [markdown]
# ### Convert the Values of The Columns that include `t` and `f` to `1` and `0`.

# %%
string_columns =list_df.select_dtypes(include=['object']).columns

# Check if each value is 't' or 'f'
tf_columns = list_df[string_columns].applymap(lambda x: x == 't' or x == 'f')

tf_columns = tf_columns.any(axis=0)
tf_columns = tf_columns[tf_columns == True].index.tolist()
tf_columns
# Out:
# ['host_is_superhost',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'is_location_exact',
#  'has_availability',
#  'requires_license',
#  'instant_bookable',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification']

# %%
bool_cols = ['host_is_superhost',
 'host_has_profile_pic',
 'host_identity_verified',
 'is_location_exact',
 'has_availability',
 'requires_license',
 'instant_bookable',
 'require_guest_profile_picture',
 'require_guest_phone_verification']

for cols in bool_cols:
    list_new_df[cols] = list_new_df[cols].replace({ 't': 1, 'f': 0 })

# %% [markdown]
# ### Remove the percentage icon of `host_response_rate` and `host_acceptance_rate` and convert to INT

# %%
list_new_df['host_response_rate'] = list_new_df['host_response_rate'].replace('N/A',0)
list_new_df['host_acceptance_rate'] = list_new_df['host_acceptance_rate'].replace('N/A',0)

list_new_df['host_response_rate'] = list_new_df['host_response_rate'].str.replace('%', '').astype(float)
list_new_df['host_acceptance_rate'] = list_new_df['host_acceptance_rate'].str.replace('%', '').astype(float)

# %%
# impute the mean of the column for NaN values (host_response_rate)
mean_value_response = list_new_df["host_response_rate"].mean()
list_new_df["host_response_rate"].fillna(value=mean_value_response,inplace=True)

# %%
# impute the mean of the column for NaN values (host_acceptance_rate)
mean_value_response = list_new_df["host_acceptance_rate"].mean()
list_new_df["host_acceptance_rate"].fillna(value=mean_value_response,inplace=True)

# %% [markdown]
# ### Handle the missing values for Numerical data types ( Impute Mode )

# %%
num_col = list_new_df.select_dtypes(include=['int', 'float']).columns
for col in num_col:
    print(col,list_new_df[col].isnull().sum())
# Out:
# host_response_rate 0
# host_acceptance_rate 0
# host_is_superhost 2
# host_listings_count 2
# host_total_listings_count 2
# host_has_profile_pic 2
# host_identity_verified 2
# is_location_exact 0
# accommodates 0
# bathrooms 16
# bedrooms 6
# beds 1
# price 0
# security_deposit 1951
# cleaning_fee 1029
# guests_included 0
# extra_people 0
# minimum_nights 0
# maximum_nights 0
# has_availability 0
# availability_30 0
# availability_60 0
# availability_90 0
# availability_365 0
# number_of_reviews 0
# review_scores_rating 647
# review_scores_accuracy 658
# review_scores_cleanliness 653
# review_scores_checkin 658
# review_scores_communication 651
# review_scores_location 655
# review_scores_value 656
# requires_license 0
# instant_bookable 0
# require_guest_profile_picture 0
# require_guest_phone_verification 0

# %%
for col in list_new_df.select_dtypes(include = ["int", "float"]):
    #check if column has null values
    if list_new_df[col].isnull().sum()>0:
        # Impute mode 
        list_new_df[col] = list_new_df[col].fillna(list_new_df[col].mode()[0])

# %%
num_col = list_new_df.select_dtypes(include=['int', 'float']).columns
for col in num_col:
    print(col,list_new_df[col].isnull().sum())
# Out:
# host_response_rate 0
# host_acceptance_rate 0
# host_is_superhost 0
# host_listings_count 0
# host_total_listings_count 0
# host_has_profile_pic 0
# host_identity_verified 0
# is_location_exact 0
# accommodates 0
# bathrooms 0
# bedrooms 0
# beds 0
# price 0
# security_deposit 0
# cleaning_fee 0
# guests_included 0
# extra_people 0
# minimum_nights 0
# maximum_nights 0
# has_availability 0
# availability_30 0
# availability_60 0
# availability_90 0
# availability_365 0
# number_of_reviews 0
# review_scores_rating 0
# review_scores_accuracy 0
# review_scores_cleanliness 0
# review_scores_checkin 0
# review_scores_communication 0
# review_scores_location 0
# review_scores_value 0
# requires_license 0
# instant_bookable 0
# require_guest_profile_picture 0
# require_guest_phone_verification 0

# %% [markdown]
# ### Handle the missing values for Categorical data types

# %%
cat_vars = [var for var in list_new_df.columns if list_new_df[var].dtypes=='O']
for col in cat_vars:
    print(col,list_new_df[col].isnull().sum())
# Out:
# summary 177
# space 568
# description 0
# neighborhood_overview 1031
# host_location 8
# host_neighbourhood 299
# neighbourhood_cleansed 0
# city 0
# state 0
# country_code 0
# property_type 1
# room_type 0
# bed_type 0
# amenities 0
# cancellation_policy 0

# %%
#Drop the null value in property_type column which has one missing value
list_new_df = list_new_df.dropna(subset=['property_type'], axis=0)

# %%
for col in list_new_df.select_dtypes(include='object'):
    #check if column has null values
    if list_new_df[col].isnull().sum()>0:
        # Impute mode 
        list_new_df[col].fillna(value="N/A", inplace=True)

# %%
cat_vars = [var for var in list_new_df.columns if list_new_df[var].dtypes=='O']
for col in cat_vars:
    print(col,list_new_df[col].isnull().sum())
# Out:
# summary 0
# space 0
# description 0
# neighborhood_overview 0
# host_location 0
# host_neighbourhood 0
# neighbourhood_cleansed 0
# city 0
# state 0
# country_code 0
# property_type 0
# room_type 0
# bed_type 0
# amenities 0
# cancellation_policy 0

# %% [markdown]
# ### Using Sentimental Analysis to convert Text to positive and negative categories

# %%
from textblob import TextBlob


# Define a function to get the sentiment polarity of each comment
def get_sentiment(comment):
    blob = TextBlob(comment)
    return blob.sentiment.polarity

# Create a new column with the sentiment label and use the sentiment label function on the "sentiment" column
list_new_df["summary_sent"] = list_new_df["summary"].apply(get_sentiment)
list_new_df["space_sent"] = list_new_df["space"].apply(get_sentiment)
list_new_df["description_sent"] = list_new_df["description"].apply(get_sentiment)
list_new_df["neighover_sent"] = list_new_df["neighborhood_overview"].apply(get_sentiment)


# Define a function to map the polarity score to a "positive" or "negative" label
def get_sentiment_label(score):
    if score >= 0:
        return "positive"
    else:
        return "negative"
list_new_df.head()
# Out:
#                                              summary  \
# 0                                                N/A
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                                space  \
# 0  Make your self at home in this charming one-be...
# 1  Beautiful, hypoallergenic apartment in an extr...
# 2  Our house is modern, light and fresh with a wa...
# 3                                                N/A
# 4  Cozy family craftman house in beautiful neighb...
#
#                                          description  \
# 0  Make your self at home in this charming one-be...
# 1  Chemically sensitive? We've removed the irrita...
# 2  New modern house built in 2013.  Spectacular s...
# 3  A charming apartment that sits atop Queen Anne...
# 4  Cozy family craftman house in beautiful neighb...
#
#                                neighborhood_overview  \
# 0                                                N/A
# 1  Queen Anne is a wonderful, truly functional vi...
# 2  Upper Queen Anne is a charming neighborhood fu...
# 3                                                N/A
# 4  We are in the beautiful neighborhood of Queen ...
#
#                         host_location  host_response_rate  \
# 0  Seattle, Washington, United States           96.000000
# 1  Seattle, Washington, United States           98.000000
# 2  Seattle, Washington, United States           67.000000
# 3  Seattle, Washington, United States           94.897389
# 4  Seattle, Washington, United States          100.000000
#
#    host_acceptance_rate  host_is_superhost host_neighbourhood  \
# 0            100.000000                0.0         Queen Anne
# 1            100.000000                1.0         Queen Anne
# 2            100.000000                0.0         Queen Anne
# 3             99.967148                0.0         Queen Anne
# 4             99.967148                0.0         Queen Anne
#
#    host_listings_count  ...  review_scores_value  requires_license  \
# 0                  3.0  ...                 10.0                 0
# 1                  6.0  ...                 10.0                 0
# 2                  2.0  ...                 10.0                 0
# 3                  1.0  ...                 10.0                 0
# 4                  2.0  ...                  9.0                 0
#
#    instant_bookable cancellation_policy require_guest_profile_picture  \
# 0                 0            moderate                             0
# 1                 0              strict                             1
# 2                 0              strict                             0
# 3                 0            flexible                             0
# 4                 0              strict                             0
#
#   require_guest_phone_verification summary_sent  space_sent description_sent  \
# 0                                0     0.000000    0.182917         0.182917
# 1                                1     0.183333    0.397868         0.348630
# 2                                0     0.392338    0.205905         0.273670
# 3                                0     0.675000    0.000000         0.675000
# 4                                0     0.550000    0.288265         0.344451
#
#   neighover_sent
# 0       0.000000
# 1       0.800000
# 2       0.371970
# 3       0.000000
# 4       0.252462
#
# [5 rows x 55 columns]

# %%
# Drop the unnecessary columns after using sentimental analysis
list_new_df.drop(['summary', 'space', 'description', 'neighborhood_overview'],axis=1,inplace=True)

# %%
# Since we are using only Seattle city and state, we decided to drop the `state`, `city`, `country_code` and `host_location`.
list_new_df.drop(['city', 'state','country_code','host_location'],axis=1,inplace=True)

# %%
list_new_df
# Out:
#       host_response_rate  host_acceptance_rate  host_is_superhost  \
# 0              96.000000            100.000000                0.0
# 1              98.000000            100.000000                1.0
# 2              67.000000            100.000000                0.0
# 3              94.897389             99.967148                0.0
# 4             100.000000             99.967148                0.0
# ...                  ...                   ...                ...
# 3812           99.000000            100.000000                0.0
# 3813          100.000000            100.000000                0.0
# 3814           94.897389             99.967148                0.0
# 3815          100.000000             99.967148                0.0
# 3816          100.000000             99.967148                0.0
#
#      host_neighbourhood  host_listings_count  host_total_listings_count  \
# 0            Queen Anne                  3.0                        3.0
# 1            Queen Anne                  6.0                        6.0
# 2            Queen Anne                  2.0                        2.0
# 3            Queen Anne                  1.0                        1.0
# 4            Queen Anne                  2.0                        2.0
# ...                 ...                  ...                        ...
# 3812              Holly                354.0                      354.0
# 3813        Portage Bay                  1.0                        1.0
# 3814                N/A                  1.0                        1.0
# 3815                N/A                  1.0                        1.0
# 3816         Queen Anne                  1.0                        1.0
#
#       host_has_profile_pic  host_identity_verified neighbourhood_cleansed  \
# 0                      1.0                     1.0        West Queen Anne
# 1                      1.0                     1.0        West Queen Anne
# 2                      1.0                     1.0        West Queen Anne
# 3                      1.0                     1.0        West Queen Anne
# 4                      1.0                     1.0        West Queen Anne
# ...                    ...                     ...                    ...
# 3812                   1.0                     1.0                Fremont
# 3813                   1.0                     1.0            Portage Bay
# 3814                   1.0                     0.0          Rainier Beach
# 3815                   1.0                     1.0           Madison Park
# 3816                   1.0                     1.0        East Queen Anne
#
#       is_location_exact  ... review_scores_value requires_license  \
# 0                     1  ...                10.0                0
# 1                     1  ...                10.0                0
# 2                     1  ...                10.0                0
# 3                     1  ...                10.0                0
# 4                     1  ...                 9.0                0
# ...                 ...  ...                 ...              ...
# 3812                  1  ...                 8.0                0
# 3813                  1  ...                10.0                0
# 3814                  0  ...                10.0                0
# 3815                  0  ...                10.0                0
# 3816                  1  ...                10.0                0
#
#       instant_bookable  cancellation_policy  require_guest_profile_picture  \
# 0                    0             moderate                              0
# 1                    0               strict                              1
# 2                    0               strict                              0
# 3                    0             flexible                              0
# 4                    0               strict                              0
# ...                ...                  ...                            ...
# 3812                 0               strict                              0
# 3813                 0             moderate                              0
# 3814                 0             moderate                              0
# 3815                 0             moderate                              0
# 3816                 0             flexible                              0
#
#       require_guest_phone_verification summary_sent space_sent  \
# 0                                    0     0.000000   0.182917
# 1                                    1     0.183333   0.397868
# 2                                    0     0.392338   0.205905
# 3                                    0     0.675000   0.000000
# 4                                    0     0.550000   0.288265
# ...                                ...          ...        ...
# 3812                                 0     0.575000   0.383664
# 3813                                 0     0.228571   0.500000
# 3814                                 0     0.450667   0.000000
# 3815                                 0     0.258333   0.296667
# 3816                                 0     0.000000   0.000000
#
#       description_sent  neighover_sent
# 0             0.182917        0.000000
# 1             0.348630        0.800000
# 2             0.273670        0.371970
# 3             0.675000        0.000000
# 4             0.344451        0.252462
# ...                ...             ...
# 3812          0.531111        0.230051
# 3813          0.215164        0.000000
# 3814          0.450667        0.000000
# 3815          0.287670        0.035795
# 3816          0.000000        0.000000
#
# [3816 rows x 47 columns]
